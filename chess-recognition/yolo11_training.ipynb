# %% [markdown]
# # Обучение YOLO 11 для детекции шахматных фигур с поддержкой Multi-Object Tracking
#
# Этот notebook содержит полный процесс обучения модели YOLO 11 для детекции шахматных фигур с поддержкой трекинга объектов.
#
# ## Особенности:
# - Использование YOLO 11 (ultralytics)
# - Поддержка Multi-Object Tracking (MOT)
# - 12 классов: белые и черные фигуры (pawn, rook, bishop, knight, king, queen)
# - Возможность дообучения на пользовательских датасетах

# %%
# Установка зависимостей
# !pip install ultralytics
# !pip install supervision
# !pip install roboflow
# !pip install pandas

# %%
import os
import cv2
import numpy as np
from pathlib import Path
from ultralytics import YOLO
import yaml
from typing import List, Tuple
import json

# %% [markdown]
# ## Настройка путей и параметров

# %%
# Настройки проекта
PROJECT_DIR = Path('/content/chess_pieces_yolo11')
DATASET_DIR = PROJECT_DIR / 'dataset'
MODELS_DIR = PROJECT_DIR / 'models'
RESULTS_DIR = PROJECT_DIR / 'results'

# Создание директорий
for dir_path in [PROJECT_DIR, DATASET_DIR, MODELS_DIR, RESULTS_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

# Параметры обучения
# ВАЖНО: Порядок классов должен соответствовать data.yaml от Roboflow!
# В датасете 13 классов (включая "bishop" на позиции 0)
NUM_CLASSES = 13
CLASS_NAMES = [
    'bishop',         # 0 - возможно старый класс, но должен быть в датасете
    'black-bishop',   # 1
    'black-king',     # 2
    'black-knight',   # 3
    'black-pawn',     # 4
    'black-queen',    # 5
    'black-rook',     # 6
    'white-bishop',   # 7
    'white-king',     # 8
    'white-knight',   # 9
    'white-pawn',     # 10
    'white-queen',    # 11
    'white-rook'      # 12
]

# Параметры модели
MODEL_SIZE = 'n'  # n, s, m, l, x (nano, small, medium, large, xlarge)
IMG_SIZE = 640
EPOCHS = 100
BATCH_SIZE = 16
PATIENCE = 50  # Early stopping patience

print(f"Проект создан: {PROJECT_DIR}")
print(f"Количество классов: {NUM_CLASSES}")
print(f"Размер модели: {MODEL_SIZE}")
print(f"\nКлассы (порядок из data.yaml):")
for i, name in enumerate(CLASS_NAMES):
    print(f"  {i}: {name}")

# %% [markdown]
# ## Подготовка датасета

# %% [markdown]
# ### Вариант 2: Загрузка датасета из Roboflow (если используется)

# %%
# Обработка архива
import zipfile
import shutil

ARCHIVE_PATH = None

# Автоматический поиск архива
if ARCHIVE_PATH is None:
    content_dir = Path("/content")
    zip_files = list(content_dir.glob("*.zip"))
    if zip_files:
        ARCHIVE_PATH = str(zip_files[0])
        print(f"Найден архив: {ARCHIVE_PATH}")
    else:
        print("Архив не найден. Укажите путь: ARCHIVE_PATH = '/content/Chess Pieces.v24-416x416_aug.yolov11.zip'")
        ARCHIVE_PATH = None

if ARCHIVE_PATH and Path(ARCHIVE_PATH).exists():
    print(f"Обработка: {ARCHIVE_PATH}")
    
    temp_extract = DATASET_DIR.parent / "temp_extract"
    temp_extract.mkdir(exist_ok=True)
    
    print("Распаковка...")
    with zipfile.ZipFile(ARCHIVE_PATH, 'r') as zip_ref:
        zip_ref.extractall(temp_extract)
    
    # Поиск структуры
    extracted_dirs = list(temp_extract.rglob("train"))
    if not extracted_dirs:
        extracted_dirs = list(temp_extract.rglob("*train*"))
    
    if extracted_dirs:
        dataset_root = extracted_dirs[0].parent
        print(f"Найден датасет: {dataset_root}")
        
        # Создаем структуру
        (DATASET_DIR / 'train' / 'images').mkdir(parents=True, exist_ok=True)
        (DATASET_DIR / 'train' / 'labels').mkdir(parents=True, exist_ok=True)
        (DATASET_DIR / 'valid' / 'images').mkdir(parents=True, exist_ok=True)
        (DATASET_DIR / 'valid' / 'labels').mkdir(parents=True, exist_ok=True)
        
        # Копируем файлы
        for split in ['train', 'valid', 'test']:
            split_dir = dataset_root / split
            if split_dir.exists():
                if (split_dir / 'images').exists():
                    shutil.copytree(split_dir / 'images', DATASET_DIR / split / 'images', dirs_exist_ok=True)
                if (split_dir / 'labels').exists():
                    shutil.copytree(split_dir / 'labels', DATASET_DIR / split / 'labels', dirs_exist_ok=True)
        
        # Копируем YAML
        for yaml_file in list(dataset_root.glob("*.yaml")) + list(dataset_root.glob("*.yml")):
            shutil.copy(yaml_file, DATASET_DIR / yaml_file.name)
        
        shutil.rmtree(temp_extract)
        print(f"✓ Датасет обработан: {DATASET_DIR}")
    else:
        print("❌ Не найдена структура датасета в архиве")
else:
    print("⚠ Архив не найден")

# %%
# Проверка датасета
if (DATASET_DIR / 'train' / 'images').exists():
    train_images = len(list((DATASET_DIR / 'train' / 'images').glob('*')))
    train_labels = len(list((DATASET_DIR / 'train' / 'labels').glob('*')))
    val_images = len(list((DATASET_DIR / 'valid' / 'images').glob('*'))) if (DATASET_DIR / 'valid' / 'images').exists() else 0
    val_labels = len(list((DATASET_DIR / 'valid' / 'labels').glob('*'))) if (DATASET_DIR / 'valid' / 'labels').exists() else 0
    test_images = len(list((DATASET_DIR / 'test' / 'images').glob('*'))) if (DATASET_DIR / 'test' / 'images').exists() else 0
    
    print(f"✓ Датасет готов")
    print(f"  Train: {train_images} изображений, {train_labels} аннотаций")
    if val_images > 0:
        print(f"  Valid: {val_images} изображений, {val_labels} аннотаций")
    if test_images > 0:
        print(f"  Test:  {test_images} изображений")
else:
    print("❌ Датасет не найден. Загрузите архив и запустите ячейку выше")

# %% [markdown]
# ## Проверка соответствия классов
#
# **ВАЖНО:** Если модель делает неправильные предсказания, проверьте соответствие классов!

# %%
# Детальная проверка классов в датасете
print("="*60)
print("ПРОВЕРКА КЛАССОВ В ДАТАСЕТЕ")
print("="*60)

# Проверяем data.yaml от Roboflow
roboflow_yaml = DATASET_DIR / 'data.yaml'
if roboflow_yaml.exists():
    with open(roboflow_yaml, 'r') as f:
        roboflow_config = yaml.safe_load(f)
    
    roboflow_names = roboflow_config.get('names', {})
    
    # Преобразуем в список, если это словарь
    if isinstance(roboflow_names, dict):
        roboflow_classes = [roboflow_names[i] for i in sorted(roboflow_names.keys())]
    else:
        roboflow_classes = roboflow_names
    
    print(f"\nКлассы в data.yaml от Roboflow:")
    for i, name in enumerate(roboflow_classes):
        print(f"  {i}: {name}")
    
    print(f"\nКлассы в коде (CLASS_NAMES):")
    for i, name in enumerate(CLASS_NAMES):
        print(f"  {i}: {name}")
    
    print(f"\n{'='*60}")
    if roboflow_classes == CLASS_NAMES:
        print("✓ Порядок классов СОВПАДАЕТ!")
    else:
        print("⚠⚠⚠ КРИТИЧЕСКАЯ ПРОБЛЕМА: Порядок классов НЕ СОВПАДАЕТ!")
        print("\nЭто объясняет неправильные предсказания!")
        print("\nРешение:")
        print("1. Измените CLASS_NAMES в ячейке 4 на порядок из data.yaml")
        print("2. ИЛИ переиндексируйте все аннотации в labels/")
        print("\nСравнение:")
        for i in range(max(len(roboflow_classes), len(CLASS_NAMES))):
            rf = roboflow_classes[i] if i < len(roboflow_classes) else "—"
            code = CLASS_NAMES[i] if i < len(CLASS_NAMES) else "—"
            match = "✓" if rf == code else "✗"
            print(f"  {i}: {rf:20s} vs {code:20s} {match}")
else:
    print("⚠ data.yaml не найден в датасете")
    print("Проверьте структуру датасета")

# %% [markdown]
# ## Создание конфигурационного файла датасета

# %%
def create_dataset_yaml(dataset_path: Path, class_names: List[str]) -> Path:
    """Создание YAML файла конфигурации датасета"""
    yaml_path = dataset_path / 'dataset.yaml'
    
    config = {
        'path': str(dataset_path.absolute()),
        'train': 'train/images',
        'val': 'valid/images',
        'test': 'test/images' if (dataset_path / 'test' / 'images').exists() else None,
        'nc': len(class_names),
        'names': {i: name for i, name in enumerate(class_names)}
    }
    
    # Удаление None значений
    config = {k: v for k, v in config.items() if v is not None}
    
    with open(yaml_path, 'w') as f:
        yaml.dump(config, f, default_flow_style=False, sort_keys=False)
    
    print(f"Конфигурация датасета создана: {yaml_path}")
    print(f"Конфигурация:\n{yaml.dump(config, default_flow_style=False)}")
    
    return yaml_path

# Проверка соответствия классов
def check_class_mapping(dataset_path: Path, expected_classes: List[str]):
    """Проверка соответствия классов в датасете"""
    roboflow_yaml = dataset_path / 'roboflow_data.yaml'
    if roboflow_yaml.exists():
        with open(roboflow_yaml, 'r') as f:
            roboflow_config = yaml.safe_load(f)
        roboflow_classes = roboflow_config.get('names', {})
        if isinstance(roboflow_classes, dict):
            roboflow_classes = [roboflow_classes[i] for i in sorted(roboflow_classes.keys())]
        print(f"\nКлассы в датасете Roboflow: {roboflow_classes}")
        print(f"Ожидаемые классы: {expected_classes}")
        
        if len(roboflow_classes) == len(expected_classes):
            if roboflow_classes == expected_classes:
                print("✓ Порядок классов совпадает!")
                return True
            else:
                print("⚠ ВНИМАНИЕ: Порядок классов отличается!")
                print("Возможно, потребуется переиндексация классов в аннотациях.")
                return False
    return True

# Создание конфигурации датасета
print("Создание конфигурации датасета...")
check_class_mapping(DATASET_DIR, CLASS_NAMES)
dataset_yaml = create_dataset_yaml(DATASET_DIR, CLASS_NAMES)
print(f"YAML файл готов: {dataset_yaml}")

# %% [markdown]
# ## Загрузка предобученной модели YOLO 11

# %%
# Загрузка предобученной модели YOLO 11
model_name = f'yolo11{MODEL_SIZE}.pt'
model = YOLO(model_name)

print(f"Модель загружена: {model_name}")
print(f"Классы модели: {model.names}")

# %% [markdown]
# ## Проверка доступности GPU
#
# **Важно для Colab:** Убедитесь, что включен GPU в настройках:
# - Runtime → Change runtime type → Hardware accelerator → GPU

# %%
# Проверка доступности GPU
import torch

def check_gpu_availability():
    """Проверка доступности GPU и вывод информации"""
    print("=" * 60)
    print("ПРОВЕРКА ДОСТУПНОСТИ GPU")
    print("=" * 60)
    
    # Проверка CUDA
    cuda_available = torch.cuda.is_available()
    print(f"CUDA доступна: {cuda_available}")
    
    if cuda_available:
        print(f"Количество GPU: {torch.cuda.device_count()}")
        for i in range(torch.cuda.device_count()):
            print(f"\nGPU {i}:")
            print(f"  Название: {torch.cuda.get_device_name(i)}")
            print(f"  Память: {torch.cuda.get_device_properties(i).total_memory / 1024**3:.2f} GB")
        
        # Текущее устройство
        current_device = torch.cuda.current_device()
        print(f"\nТекущее устройство: GPU {current_device}")
        print(f"Имя устройства: {torch.cuda.get_device_name(current_device)}")
        
        # Использование памяти
        allocated = torch.cuda.memory_allocated() / 1024**3
        reserved = torch.cuda.memory_reserved() / 1024**3
        print(f"\nИспользование памяти GPU:")
        print(f"  Выделено: {allocated:.2f} GB")
        print(f"  Зарезервировано: {reserved:.2f} GB")
        
        return '0'  # Использовать первую GPU
    else:
        print("\n⚠ ВНИМАНИЕ: GPU не доступна!")
        print("Обучение будет выполняться на CPU (очень медленно)")
        print("\nДля Colab:")
        print("1. Runtime → Change runtime type")
        print("2. Hardware accelerator → GPU")
        print("3. Сохраните и перезапустите runtime")
        return 'cpu'

# Проверка GPU
DEVICE = check_gpu_availability()
print(f"\n{'='*60}")
print(f"Будет использовано устройство: {DEVICE}")
print(f"{'='*60}\n")

# %% [markdown]
# ## Обучение модели
#
# **Важно:** Перед обучением убедитесь, что:
# 1. Датасет подготовлен и находится в `DATASET_DIR`
# 2. Создан файл `dataset.yaml` с правильной конфигурацией
# 3. У вас достаточно GPU памяти (рекомендуется минимум 8GB для batch_size=16)

# %%
# Обучение модели
# Убедитесь, что dataset_yaml указывает на правильный путь к конфигурации

def train_model(
    model: YOLO,
    dataset_yaml: str,
    epochs: int = EPOCHS,
    imgsz: int = IMG_SIZE,
    batch: int = BATCH_SIZE,
    patience: int = PATIENCE,
    device: str = '0',  # '0' для GPU, 'cpu' для CPU
    project: str = str(RESULTS_DIR),
    name: str = 'chess_pieces_yolo11',
    save: bool = True,
    save_period: int = 10,  # Сохранять чекпоинт каждые N эпох
):
    """Обучение модели YOLO 11"""
    
    results = model.train(
        data=dataset_yaml,
        epochs=epochs,
        imgsz=imgsz,
        batch=batch,
        patience=patience,
        device=device,
        project=project,
        name=name,
        save=save,
        save_period=save_period,
        # Дополнительные параметры для улучшения качества
        optimizer='AdamW',  # AdamW обычно лучше для fine-tuning
        lr0=0.001,  # Начальная скорость обучения
        lrf=0.01,  # Финальная скорость обучения (lr0 * lrf)
        momentum=0.937,
        weight_decay=0.0005,
        warmup_epochs=3.0,
        warmup_momentum=0.8,
        warmup_bias_lr=0.1,
        box=7.5,  # Box loss gain
        cls=0.5,  # Class loss gain
        dfl=1.5,  # DFL loss gain
        pose=12.0,  # Pose loss gain (если используется)
        kobj=1.0,  # Keypoint obj loss gain (если используется)
        label_smoothing=0.0,
        nbs=64,  # Nominal batch size
        hsv_h=0.015,  # Image HSV-Hue augmentation
        hsv_s=0.7,  # Image HSV-Saturation augmentation
        hsv_v=0.4,  # Image HSV-Value augmentation
        degrees=0.0,  # Image rotation (+/- deg)
        translate=0.1,  # Image translation (+/- fraction)
        scale=0.5,  # Image scale (+/- gain)
        shear=0.0,  # Image shear (+/- deg)
        perspective=0.0,  # Image perspective (+/- fraction)
        flipud=0.0,  # Image flip up-down (probability)
        fliplr=0.5,  # Image flip left-right (probability)
        mosaic=1.0,  # Image mosaic (probability)
        mixup=0.0,  # Image mixup (probability)
        copy_paste=0.0,  # Segment copy-paste (probability)
    )
    
    return results

# Запуск обучения
print("Начинаем обучение модели...")
print(f"Конфигурация датасета: {dataset_yaml}")
print(f"Устройство для обучения: {DEVICE}")
results = train_model(model, str(dataset_yaml), epochs=EPOCHS, device=DEVICE)
print("Обучение завершено!")

# %% [markdown]
# ## Визуализация результатов обучения

# %%
import matplotlib.pyplot as plt
from pathlib import Path

def visualize_training_results(results_dir: Path, run_name: str = 'chess_pieces_yolo11'):
    """Визуализация результатов обучения"""
    results_path = results_dir / run_name
    
    # Поиск последнего запуска
    if not results_path.exists():
        # Поиск последней директории с результатами
        runs = sorted(results_path.parent.glob('*'), key=lambda x: x.stat().st_mtime, reverse=True)
        if runs:
            results_path = runs[0]
        else:
            print("Результаты обучения не найдены")
            return
    
    # Загрузка графиков
    results_image = results_path / 'results.png'
    confusion_matrix = results_path / 'confusion_matrix.png'
    train_batch = results_path / 'train_batch0.jpg'
    val_batch = results_path / 'val_batch0_pred.jpg'
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    if results_image.exists():
        img = plt.imread(results_image)
        axes[0, 0].imshow(img)
        axes[0, 0].axis('off')
        axes[0, 0].set_title('Training Results')
    
    if confusion_matrix.exists():
        img = plt.imread(confusion_matrix)
        axes[0, 1].imshow(img)
        axes[0, 1].axis('off')
        axes[0, 1].set_title('Confusion Matrix')
    
    if train_batch.exists():
        img = plt.imread(train_batch)
        axes[1, 0].imshow(img)
        axes[1, 0].axis('off')
        axes[1, 0].set_title('Train Batch')
    
    if val_batch.exists():
        img = plt.imread(val_batch)
        axes[1, 1].imshow(img)
        axes[1, 1].axis('off')
        axes[1, 1].set_title('Validation Predictions')
    
    plt.tight_layout()
    plt.show()
    
    # Вывод метрик
    metrics_file = results_path / 'results.csv'
    if metrics_file.exists():
        import pandas as pd
        df = pd.read_csv(metrics_file)
        print("\nПоследние метрики:")
        print(df.tail())
    
    return results_path

# Раскомментируйте после обучения
# best_model_path = visualize_training_results(RESULTS_DIR)

# %% [markdown]
# ## Тестирование обученной модели
#
# **Важно:**
# - **Валидационный набор (valid)** используется для настройки гиперпараметров и ранней остановки во время обучения
# - **Тестовый набор (test)** используется для финальной оценки качества модели и не должен использоваться во время обучения
# - Если тестовый набор отсутствует, можно использовать валидационный для промежуточной проверки, но для финальной оценки лучше использовать отдельный тестовый набор

# %%
# Загрузка лучшей модели после обучения
def load_best_model(results_dir: Path, run_name: str = 'chess_pieces_yolo11'):
    """Загрузка лучшей модели из результатов обучения"""
    results_path = results_dir / run_name
    
    # Поиск последнего запуска
    if not results_path.exists():
        runs = sorted(results_path.parent.glob('*'), key=lambda x: x.stat().st_mtime, reverse=True)
        if runs:
            results_path = runs[0]
            print(f"Используется последний запуск: {results_path}")
        else:
            raise FileNotFoundError("Результаты обучения не найдены")
    
    best_model_path = results_path / 'weights' / 'best.pt'
    
    if not best_model_path.exists():
        raise FileNotFoundError(f"Лучшая модель не найдена: {best_model_path}")
    
    model = YOLO(str(best_model_path))
    print(f"Модель загружена: {best_model_path}")
    return model, str(best_model_path)

# Загрузка модели (раскомментируйте после обучения)
# best_model, best_model_path = load_best_model(RESULTS_DIR)

# %%
# ПРОМЕЖУТОЧНАЯ ПРОВЕРКА: Тестирование на валидационном наборе
# (Используйте только для промежуточной проверки, не для финальной оценки!)
def test_on_validation_images(
    model: YOLO,
    dataset_dir: Path,
    num_images: int = 5,
    conf_threshold: float = 0.25,
    save_dir: Path = None
):
    """Промежуточное тестирование модели на случайных изображениях из валидационного набора"""
    import random
    from PIL import Image
    
    val_images_dir = dataset_dir / 'valid' / 'images'
    if not val_images_dir.exists():
        print(f"Валидационная директория не найдена: {val_images_dir}")
        return
    
    # Получаем список изображений
    image_files = list(val_images_dir.glob('*.jpg')) + list(val_images_dir.glob('*.png'))
    if not image_files:
        print("Изображения не найдены в валидационном наборе")
        return
    
    # Выбираем случайные изображения
    test_images = random.sample(image_files, min(num_images, len(image_files)))
    
    if save_dir:
        save_dir.mkdir(parents=True, exist_ok=True)
    
    print(f"⚠ ПРОМЕЖУТОЧНАЯ ПРОВЕРКА на валидационном наборе")
    print(f"Тестирование на {len(test_images)} изображениях...\n")
    
    for i, img_path in enumerate(test_images, 1):
        print(f"\n{'='*60}")
        print(f"Изображение {i}/{len(test_images)}: {img_path.name}")
        print(f"{'='*60}")
        
        # Предсказание
        results = model.predict(
            source=str(img_path),
            conf=conf_threshold,
            save=save_dir is not None,
            project=str(save_dir.parent) if save_dir else None,
            name=save_dir.name if save_dir else 'predict',
            exist_ok=True
        )
        
        result = results[0]
        if result.boxes is not None and len(result.boxes) > 0:
            print(f"Найдено фигур: {len(result.boxes)}")
            
            # Группировка по классам
            class_counts = {}
            for box in result.boxes:
                cls = int(box.cls)
                conf = float(box.conf)
                class_name = model.names[cls]
                
                if class_name not in class_counts:
                    class_counts[class_name] = []
                class_counts[class_name].append(conf)
            
            # Вывод статистики
            for class_name, confidences in sorted(class_counts.items()):
                avg_conf = sum(confidences) / len(confidences)
                print(f"  {class_name}: {len(confidences)} шт. (средняя уверенность: {avg_conf:.3f})")
        else:
            print("Фигуры не обнаружены")
    
    print(f"\n{'='*60}")
    print("Промежуточная проверка завершена!")
    if save_dir:
        print(f"Результаты сохранены в: {save_dir}")

# Раскомментируйте для промежуточной проверки (НЕ для финальной оценки!)
# test_on_validation_images(
#     model=best_model,
#     dataset_dir=DATASET_DIR,
#     num_images=5,
#     conf_threshold=0.25,
#     save_dir=RESULTS_DIR / 'validation_predictions'
# )

# %% [markdown]
# ### ФИНАЛЬНОЕ ТЕСТИРОВАНИЕ на тестовом наборе

# %%
# ФИНАЛЬНОЕ ТЕСТИРОВАНИЕ: Тестирование на тестовом наборе
def test_on_test_set(
    model: YOLO,
    dataset_dir: Path,
    num_images: int = None,  # None = все изображения
    conf_threshold: float = 0.25,
    save_dir: Path = None
):
    """Финальное тестирование модели на тестовом наборе (не использованном при обучении)"""
    import random
    
    test_images_dir = dataset_dir / 'test' / 'images'
    
    if not test_images_dir.exists():
        print("⚠ ВНИМАНИЕ: Тестовый набор не найден!")
        print("Используется валидационный набор для финальной оценки (не рекомендуется)")
        test_images_dir = dataset_dir / 'valid' / 'images'
        if not test_images_dir.exists():
            print(f"Ошибка: Валидационная директория также не найдена: {test_images_dir}")
            return
    
    # Получаем список изображений
    image_files = list(test_images_dir.glob('*.jpg')) + list(test_images_dir.glob('*.png'))
    if not image_files:
        print("Изображения не найдены в тестовом наборе")
        return
    
    # Выбираем изображения
    if num_images is None:
        test_images = image_files
        print(f"✓ ФИНАЛЬНОЕ ТЕСТИРОВАНИЕ на ВСЕМ тестовом наборе ({len(test_images)} изображений)")
    else:
        test_images = random.sample(image_files, min(num_images, len(image_files)))
        print(f"✓ ФИНАЛЬНОЕ ТЕСТИРОВАНИЕ на {len(test_images)} изображениях из тестового набора")
    
    if save_dir:
        save_dir.mkdir(parents=True, exist_ok=True)
    
    # Статистика по всем изображениям
    total_detections = 0
    total_by_class = {}
    all_confidences = []
    
    print(f"\n{'='*60}")
    
    for i, img_path in enumerate(test_images, 1):
        if i % 10 == 0 or i == len(test_images):
            print(f"Обработано: {i}/{len(test_images)}")
        
        # Предсказание
        results = model.predict(
            source=str(img_path),
            conf=conf_threshold,
            save=save_dir is not None,
            project=str(save_dir.parent) if save_dir else None,
            name=save_dir.name if save_dir else 'test_predictions',
            exist_ok=True,
            verbose=False
        )
        
        result = results[0]
        if result.boxes is not None and len(result.boxes) > 0:
            total_detections += len(result.boxes)
            
            for box in result.boxes:
                cls = int(box.cls)
                conf = float(box.conf)
                class_name = model.names[cls]
                
                if class_name not in total_by_class:
                    total_by_class[class_name] = {'count': 0, 'confidences': []}
                
                total_by_class[class_name]['count'] += 1
                total_by_class[class_name]['confidences'].append(conf)
                all_confidences.append(conf)
    
    # Итоговая статистика
    print(f"\n{'='*60}")
    print("ИТОГОВАЯ СТАТИСТИКА ТЕСТИРОВАНИЯ")
    print(f"{'='*60}")
    print(f"Всего протестировано изображений: {len(test_images)}")
    print(f"Всего обнаружено фигур: {total_detections}")
    if total_detections > 0:
        print(f"Средняя уверенность: {sum(all_confidences) / len(all_confidences):.3f}")
        print(f"Минимальная уверенность: {min(all_confidences):.3f}")
        print(f"Максимальная уверенность: {max(all_confidences):.3f}")
    
    print(f"\nСтатистика по классам:")
    print(f"{'Класс':<20} {'Количество':<12} {'Средняя уверенность':<20} {'Мин/Макс'}")
    print(f"{'-'*70}")
    
    for class_name in sorted(total_by_class.keys()):
        stats = total_by_class[class_name]
        avg_conf = sum(stats['confidences']) / len(stats['confidences'])
        min_conf = min(stats['confidences'])
        max_conf = max(stats['confidences'])
        print(f"{class_name:<20} {stats['count']:<12} {avg_conf:<20.3f} {min_conf:.3f}/{max_conf:.3f}")
    
    print(f"\n{'='*60}")
    print("Финальное тестирование завершено!")
    if save_dir:
        print(f"Результаты сохранены в: {save_dir}")
    
    return {
        'total_images': len(test_images),
        'total_detections': total_detections,
        'avg_confidence': sum(all_confidences) / len(all_confidences) if all_confidences else 0,
        'by_class': total_by_class
    }

# Раскомментируйте для финального тестирования на тестовом наборе
# test_stats = test_on_test_set(
#     model=best_model,
#     dataset_dir=DATASET_DIR,
#     num_images=None,  # None = все изображения, или укажите число для выборки
#     conf_threshold=0.25,
#     save_dir=RESULTS_DIR / 'test_set_predictions'
# )

# %%
# Детальное тестирование одного изображения из тестового набора
def test_single_test_image(
    model: YOLO,
    dataset_dir: Path,
    image_name: str = None,  # Если None - случайное изображение
    conf_threshold: float = 0.25,
    show_image: bool = True
):
    """Детальное тестирование на одном изображении из тестового набора"""
    import random
    
    test_images_dir = dataset_dir / 'test' / 'images'
    
    if not test_images_dir.exists():
        print("⚠ Тестовый набор не найден, используем валидационный")
        test_images_dir = dataset_dir / 'valid' / 'images'
        if not test_images_dir.exists():
            print(f"Ошибка: Директория не найдена: {test_images_dir}")
            return
    
    image_files = list(test_images_dir.glob('*.jpg')) + list(test_images_dir.glob('*.png'))
    if not image_files:
        print("Изображения не найдены")
        return
    
    if image_name:
        img_path = test_images_dir / image_name
        if not img_path.exists():
            print(f"Изображение не найдено: {image_name}")
            return
    else:
        img_path = random.choice(image_files)
    
    print(f"Тестирование изображения из {'тестового' if (dataset_dir / 'test' / 'images').exists() else 'валидационного'} набора: {img_path.name}\n")
    
    return test_single_image_detailed(
        model=model,
        image_path=str(img_path),
        conf_threshold=conf_threshold,
        show_image=show_image
    )

# Раскомментируйте для детального тестирования одного изображения из тестового набора
# test_single_test_image(
#     model=best_model,
#     dataset_dir=DATASET_DIR,
#     image_name=None,  # None = случайное, или укажите имя файла
#     conf_threshold=0.25,
#     show_image=True
# )

# %%
# Детальное тестирование на одном изображении с визуализацией
def test_single_image_detailed(
    model: YOLO,
    image_path: str,
    conf_threshold: float = 0.25,
    show_image: bool = True
):
    """Детальное тестирование на одном изображении с подробной информацией"""
    import matplotlib.pyplot as plt
    from PIL import Image
    import numpy as np
    
    # Загрузка изображения
    img = Image.open(image_path)
    img_array = np.array(img)
    
    # Предсказание
    results = model.predict(
        source=image_path,
        conf=conf_threshold,
        save=False
    )
    
    result = results[0]
    
    # Визуализация
    if show_image:
        fig, axes = plt.subplots(1, 2, figsize=(16, 8))
        
        # Оригинальное изображение
        axes[0].imshow(img_array)
        axes[0].axis('off')
        axes[0].set_title('Оригинальное изображение', fontsize=14)
        
        # Изображение с предсказаниями
        annotated_img = result.plot()
        axes[1].imshow(annotated_img)
        axes[1].axis('off')
        axes[1].set_title('Результаты детекции', fontsize=14)
        
        plt.tight_layout()
        plt.show()
    
    # Детальная информация
    print(f"\n{'='*60}")
    print(f"Результаты детекции для: {Path(image_path).name}")
    print(f"{'='*60}")
    
    if result.boxes is not None and len(result.boxes) > 0:
        print(f"\nВсего обнаружено фигур: {len(result.boxes)}\n")
        
        # Создаем таблицу результатов
        detections = []
        for i, box in enumerate(result.boxes, 1):
            cls = int(box.cls)
            conf = float(box.conf)
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            w = x2 - x1
            h = y2 - y1
            
            detections.append({
                '№': i,
                'Класс': model.names[cls],
                'Уверенность': f"{conf:.3f}",
                'Координаты': f"({int(x1)}, {int(y1)})",
                'Размер': f"{int(w)}x{int(h)}"
            })
        
        # Вывод таблицы
        import pandas as pd
        df = pd.DataFrame(detections)
        print(df.to_string(index=False))
        
        # Статистика по классам
        print(f"\n{'='*60}")
        print("Статистика по классам:")
        print(f"{'='*60}")
        
        class_stats = {}
        for box in result.boxes:
            cls = int(box.cls)
            conf = float(box.conf)
            class_name = model.names[cls]
            
            if class_name not in class_stats:
                class_stats[class_name] = {'count': 0, 'confidences': []}
            
            class_stats[class_name]['count'] += 1
            class_stats[class_name]['confidences'].append(conf)
        
        for class_name, stats in sorted(class_stats.items()):
            avg_conf = sum(stats['confidences']) / len(stats['confidences'])
            min_conf = min(stats['confidences'])
            max_conf = max(stats['confidences'])
            print(f"{class_name:20s}: {stats['count']:2d} шт. | "
                  f"уверенность: {avg_conf:.3f} (мин: {min_conf:.3f}, макс: {max_conf:.3f})")
    else:
        print("\nФигуры не обнаружены на изображении")
    
    return result

# Пример использования (раскомментируйте и укажите путь к изображению)
# test_image_path = str(DATASET_DIR / 'valid' / 'images' / 'ваше_изображение.jpg')
# result = test_single_image_detailed(
#     model=best_model,
#     image_path=test_image_path,
#     conf_threshold=0.25,
#     show_image=True
# )

# %%
# Быстрый тест на случайном изображении из валидационного набора
def quick_test_random_image(model: YOLO, dataset_dir: Path, conf_threshold: float = 0.25):
    """Быстрый тест на случайном изображении"""
    import random
    
    val_images_dir = dataset_dir / 'valid' / 'images'
    if not val_images_dir.exists():
        print(f"Валидационная директория не найдена: {val_images_dir}")
        return
    
    image_files = list(val_images_dir.glob('*.jpg')) + list(val_images_dir.glob('*.png'))
    if not image_files:
        print("Изображения не найдены")
        return
    
    # Выбираем случайное изображение
    random_image = random.choice(image_files)
    print(f"Тестирование на случайном изображении: {random_image.name}\n")
    
    return test_single_image_detailed(
        model=model,
        image_path=str(random_image),
        conf_threshold=conf_threshold,
        show_image=True
    )

# Раскомментируйте после обучения и загрузки модели для быстрого теста
# quick_test_random_image(best_model, DATASET_DIR, conf_threshold=0.25)

# %%
def export_best_model(results_dir: Path, run_name: str = 'chess_pieces_yolo11', 
                      export_formats: List[str] = ['onnx', 'torchscript']):
    """Экспорт лучшей модели в различные форматы"""
    results_path = results_dir / run_name
    
    # Поиск последнего запуска
    if not results_path.exists():
        runs = sorted(results_path.parent.glob('*'), key=lambda x: x.stat().st_mtime, reverse=True)
        if runs:
            results_path = runs[0]
        else:
            print("Результаты обучения не найдены")
            return None
    
    best_model_path = results_path / 'weights' / 'best.pt'
    
    if not best_model_path.exists():
        print(f"Лучшая модель не найдена: {best_model_path}")
        return None
    
    # Загрузка лучшей модели
    best_model = YOLO(str(best_model_path))
    
    # Экспорт в различные форматы
    exported_models = {}
    for fmt in export_formats:
        try:
            export_path = best_model.export(format=fmt, imgsz=IMG_SIZE)
            exported_models[fmt] = export_path
            print(f"Модель экспортирована в {fmt}: {export_path}")
        except Exception as e:
            print(f"Ошибка при экспорте в {fmt}: {e}")
    
    # Копирование лучшей модели в директорию моделей
    import shutil
    target_model_path = MODELS_DIR / f'chess_pieces_yolo11_{MODEL_SIZE}_best.pt'
    shutil.copy(best_model_path, target_model_path)
    print(f"Лучшая модель скопирована: {target_model_path}")
    
    return {
        'best_pt': str(best_model_path),
        'exported': exported_models,
        'copied': str(target_model_path)
    }

# Раскомментируйте для экспорта модели
# export_info = export_best_model(RESULTS_DIR)

# %% [markdown]
# ## Тестирование модели с Multi-Object Tracking
#
# YOLO 11 поддерживает встроенный трекинг. Для использования трекинга нужно использовать метод `track()` вместо `predict()`.

# %%
def test_model_with_tracking(
    model_path: str,
    video_path: str = None,
    image_path: str = None,
    conf_threshold: float = 0.25,
    iou_threshold: float = 0.45,
    tracker: str = 'bytetrack.yaml',  # 'bytetrack.yaml' или 'botsort.yaml'
    save: bool = True,
    show: bool = True,
):
    """Тестирование модели с поддержкой трекинга"""
    
    # Загрузка модели
    model = YOLO(model_path)
    
    if video_path:
        # Обработка видео с трекингом
        results = model.track(
            source=video_path,
            conf=conf_threshold,
            iou=iou_threshold,
            tracker=tracker,
            save=save,
            show=show,
            line_width=2,
        )
        
        # Результаты трекинга содержат track_ids
        for result in results:
            if result.boxes is not None:
                boxes = result.boxes
                for i, box in enumerate(boxes):
                    # Получение track_id
                    track_id = int(box.id) if box.id is not None else None
                    cls = int(box.cls)
                    conf = float(box.conf)
                    
                    print(f"Track ID: {track_id}, Class: {model.names[cls]}, Confidence: {conf:.2f}")
    
    elif image_path:
        # Обработка изображения (трекинг не применим к одному изображению)
        results = model.predict(
            source=image_path,
            conf=conf_threshold,
            iou=iou_threshold,
            save=save,
            show=show,
            line_width=2,
        )
        
        for result in results:
            if result.boxes is not None:
                boxes = result.boxes
                for i, box in enumerate(boxes):
                    cls = int(box.cls)
                    conf = float(box.conf)
                    print(f"Class: {model.names[cls]}, Confidence: {conf:.2f}")
    
    return results

# Пример использования (раскомментируйте и укажите пути)
# test_results = test_model_with_tracking(
#     model_path=str(MODELS_DIR / 'chess_pieces_yolo11_n_best.pt'),
#     video_path='/path/to/test_video.mp4',
#     conf_threshold=0.25,
#     tracker='bytetrack.yaml'
# )

# %% [markdown]
# ## Сохранение конфигурации модели для использования в приложении

# %%
def save_model_config(
    model_path: str,
    class_names: List[str],
    output_path: Path,
    model_size: str = 'n',
    img_size: int = 640,
    conf_threshold: float = 0.25,
    iou_threshold: float = 0.45,
):
    """Сохранение конфигурации модели для использования в приложении"""
    
    config = {
        'model_path': str(model_path),
        'model_size': model_size,
        'img_size': img_size,
        'num_classes': len(class_names),
        'class_names': class_names,
        'class_mapping': {i: name for i, name in enumerate(class_names)},
        'conf_threshold': conf_threshold,
        'iou_threshold': iou_threshold,
        'tracker': 'bytetrack.yaml',  # Используемый трекер
        'version': 'yolo11',
        'description': 'YOLO 11 модель для детекции шахматных фигур с поддержкой трекинга'
    }
    
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(config, f, indent=2, ensure_ascii=False)
    
    print(f"Конфигурация модели сохранена: {output_path}")
    return config

# Пример сохранения конфигурации
# model_config = save_model_config(
#     model_path=str(MODELS_DIR / 'chess_pieces_yolo11_n_best.pt'),
#     class_names=CLASS_NAMES,
#     output_path=MODELS_DIR / 'model_config.json',
#     model_size=MODEL_SIZE,
#     img_size=IMG_SIZE
# )
